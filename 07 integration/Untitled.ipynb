# %%
import pandas as pd

acs_data = pd.read_csv('acs2017_census_tract_data.csv')
covid_data = pd.read_csv('COVID_county_data.csv')

county_info = acs_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

county_info.columns = ['State', 'Name', 'Population', 'Poverty', 'PerCapitaIncome']

county_info['ID'] = range(1, len(county_info) + 1)

covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month

covid_data = covid_data.merge(county_info, left_on=['state', 'county'], right_on=['State', 'Name'])

covid_monthly = covid_data.groupby(['ID', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

covid_monthly.columns = ['ID', 'Month', 'Cases', 'Deaths']

print("County_Info DataFrame:")
print(county_info.head())

print("\nCOVID_monthly DataFrame:")
print(covid_monthly.head())
# Out:
# County_Info DataFrame:
#      State            Name  Population    Poverty  PerCapitaIncome  ID
# 0  Alabama  Autauga County       55036  14.558333     26588.166667   1
# 1  Alabama  Baldwin County      203360  12.874194     29130.709677   2
# 2  Alabama  Barbour County       26201  27.755556     17891.666667   3
# 3  Alabama     Bibb County       22580  13.925000     21799.000000   4
# 4  Alabama   Blount County       57667  16.422222     21598.444444   5
#
# COVID_monthly DataFrame:
#    ID  Month  Cases  Deaths
# 0  68      1   1550     0.0
# 1  68      2   5836     2.0
# 2  68      6     38     0.0
# 3  68      7     73     0.0
# 4  68      8    121     0.0

# %%
import pandas as pd

# Read the data
acs_data = pd.read_csv('acs2017_census_tract_data.csv')
covid_data = pd.read_csv('COVID_county_data.csv')

# Group and aggregate the ACS data
county_info = acs_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Rename columns for clarity
county_info.columns = ['State', 'Name', 'Population', 'Poverty', 'PerCapitaIncome']

# Add a unique ID to each county
county_info['ID'] = range(1, len(county_info) + 1)

# Convert the date column to datetime and extract the month
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month

# Merge the COVID data with the county information
covid_data = covid_data.merge(county_info, left_on=['state', 'county'], right_on=['State', 'Name'])

# Group by ID and Month, then aggregate cases and deaths
covid_monthly = covid_data.groupby(['ID', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_monthly.columns = ['ID', 'Month', 'Cases', 'Deaths']

# Print the first few rows of each DataFrame
print("County_Info DataFrame:")
print(county_info.head())

print("\nCOVID_monthly DataFrame:")
print(covid_monthly.head())

# Verify the IDs in covid_monthly are consistent with county_info
unique_county_ids = county_info['ID'].nunique()
unique_covid_ids = covid_monthly['ID'].nunique()

print(f"\nUnique IDs in county_info: {unique_county_ids}")
print(f"Unique IDs in covid_monthly: {unique_covid_ids}")

# Check if all IDs in covid_monthly exist in county_info
missing_ids = set(covid_monthly['ID']) - set(county_info['ID'])
if not missing_ids:
    print("All IDs in covid_monthly are present in county_info.")
else:
    print(f"Missing IDs in county_info: {missing_ids}")
# Out:
# County_Info DataFrame:
#      State            Name  Population    Poverty  PerCapitaIncome  ID
# 0  Alabama  Autauga County       55036  14.558333     26588.166667   1
# 1  Alabama  Baldwin County      203360  12.874194     29130.709677   2
# 2  Alabama  Barbour County       26201  27.755556     17891.666667   3
# 3  Alabama     Bibb County       22580  13.925000     21799.000000   4
# 4  Alabama   Blount County       57667  16.422222     21598.444444   5
#
# COVID_monthly DataFrame:
#    ID  Month  Cases  Deaths
# 0  68      1   1550     0.0
# 1  68      2   5836     2.0
# 2  68      6     38     0.0
# 3  68      7     73     0.0
# 4  68      8    121     0.0
#
# Unique IDs in county_info: 3220
# Unique IDs in covid_monthly: 66
# All IDs in covid_monthly are present in county_info.

# %%
import pandas as pd

# Read the data
acs_data = pd.read_csv('acs2017_census_tract_data.csv')
covid_data = pd.read_csv('COVID_county_data.csv')

# Group and aggregate the ACS data
county_info = acs_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Rename columns for clarity
county_info.columns = ['State', 'Name', 'Population', 'Poverty', 'PerCapitaIncome']

# Add a unique ID to each county
county_info['ID'] = range(1, len(county_info) + 1)

# Convert the date column to datetime and extract the month
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month

# Merge the COVID data with the county information
covid_data = covid_data.merge(county_info, left_on=['state', 'county'], right_on=['State', 'Name'])

# Group by ID and Month, then aggregate cases and deaths
covid_monthly = covid_data.groupby(['ID', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_monthly.columns = ['ID', 'Month', 'Cases', 'Deaths']

# Print the first few rows of each DataFrame
print("County_Info DataFrame:")
print(county_info.head())

print("\nCOVID_monthly DataFrame:")
print(covid_monthly.head())

# Verify the IDs in covid_monthly are consistent with county_info
unique_county_ids = county_info['ID'].nunique()
unique_covid_ids = covid_monthly['ID'].nunique()

print(f"\nUnique IDs in county_info: {unique_county_ids}")
print(f"Unique IDs in covid_monthly: {unique_covid_ids}")

# Check if all IDs in covid_monthly exist in county_info
missing_ids = set(covid_monthly['ID']) - set(county_info['ID'])
if not missing_ids:
    print("All IDs in covid_monthly are present in county_info.")
else:
    print(f"Missing IDs in county_info: {missing_ids}")

# Check if each ID-Month combination is unique
id_month_counts = covid_monthly.groupby(['ID', 'Month']).size()
duplicate_id_months = id_month_counts[id_month_counts > 1]

if duplicate_id_months.empty:
    print("\nEach county-month combination in covid_monthly is unique.")
else:
    print("\nThere are duplicate county-month combinations in covid_monthly:")
    print(duplicate_id_months)
# Out:
# County_Info DataFrame:
#      State            Name  Population    Poverty  PerCapitaIncome  ID
# 0  Alabama  Autauga County       55036  14.558333     26588.166667   1
# 1  Alabama  Baldwin County      203360  12.874194     29130.709677   2
# 2  Alabama  Barbour County       26201  27.755556     17891.666667   3
# 3  Alabama     Bibb County       22580  13.925000     21799.000000   4
# 4  Alabama   Blount County       57667  16.422222     21598.444444   5
#
# COVID_monthly DataFrame:
#    ID  Month  Cases  Deaths
# 0  68      1   1550     0.0
# 1  68      2   5836     2.0
# 2  68      6     38     0.0
# 3  68      7     73     0.0
# 4  68      8    121     0.0
#
# Unique IDs in county_info: 3220
# Unique IDs in covid_monthly: 66
# All IDs in covid_monthly are present in county_info.
#
# Each county-month combination in covid_monthly is unique.

# %%
import pandas as pd

# Read the data
acs_data = pd.read_csv('acs2017_census_tract_data.csv')
covid_data = pd.read_csv('COVID_county_data.csv')

# Group and aggregate the ACS data
county_info = acs_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Rename columns for clarity
county_info.columns = ['State', 'Name', 'Population', 'Poverty', 'PerCapitaIncome']

# Add a unique ID to each county
county_info['ID'] = range(1, len(county_info) + 1)

# Convert the date column to datetime and extract the month
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month

# Merge the COVID data with the county information
covid_data = covid_data.merge(county_info, left_on=['state', 'county'], right_on=['State', 'Name'])

# Group by ID and Month, then aggregate cases and deaths
covid_monthly = covid_data.groupby(['ID', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_monthly.columns = ['ID', 'Month', 'Cases', 'Deaths']

# Find Malheur County, Oregon in county_info and get its ID
malheur_county_info = county_info[(county_info['Name'] == 'Malheur County') & (county_info['State'] == 'Oregon')]
malheur_county_id = malheur_county_info['ID'].values[0]

print(f"ID for Malheur County, Oregon: {malheur_county_id}")

# Use the ID to find cases and deaths in COVID_monthly for August 2020
malheur_august_data = covid_monthly[(covid_monthly['ID'] == malheur_county_id) & (covid_monthly['Month'] == 8)]

print(f"COVID data for Malheur County, Oregon in August 2020:")
print(malheur_august_data[['Cases', 'Deaths']])
# Out:
# ID for Malheur County, Oregon: 2231
# COVID data for Malheur County, Oregon in August 2020:
# Empty DataFrame
# Columns: [Cases, Deaths]
# Index: []

# %%
import pandas as pd

# Read the data
acs_data = pd.read_csv('acs2017_census_tract_data.csv')
covid_data = pd.read_csv('COVID_county_data.csv')

# Group and aggregate the ACS data
county_info = acs_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Rename columns for clarity
county_info.columns = ['State', 'Name', 'Population', 'Poverty', 'PerCapitaIncome']

# Add a unique ID to each county
county_info['ID'] = range(1, len(county_info) + 1)

# Convert the date column to datetime and extract the month
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month

# Merge the COVID data with the county information
covid_data = covid_data.merge(county_info, left_on=['state', 'county'], right_on=['State', 'Name'])

# Ensure there is a row for each county and each month
all_ids = county_info['ID'].unique()
all_months = covid_data['Month'].unique()

index = pd.MultiIndex.from_product([all_ids, all_months], names=['ID', 'Month'])
covid_monthly_full = pd.DataFrame(index=index).reset_index()

# Group by ID and Month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Merge the full DataFrame with the aggregated data
covid_monthly = covid_monthly_full.merge(covid_monthly_agg, on=['ID', 'Month'], how='left').fillna(0)

# Rename columns for clarity
covid_monthly.columns = ['ID', 'Month', 'Cases', 'Deaths']

# Print the first few rows of each DataFrame
print("County_Info DataFrame:")
print(county_info.head())

print("\nCOVID_monthly DataFrame:")
print(covid_monthly.head())

# Find Malheur County, Oregon in county_info and get its ID
malheur_county_info = county_info[(county_info['Name'] == 'Malheur County') & (county_info['State'] == 'Oregon')]
malheur_county_id = malheur_county_info['ID'].values[0]

print(f"\nID for Malheur County, Oregon: {malheur_county_id}")

# Use the ID to find cases and deaths in COVID_monthly for August 2020
malheur_august_data = covid_monthly[(covid_monthly['ID'] == malheur_county_id) & (covid_monthly['Month'] == 8)]

print(f"\nCOVID data for Malheur County, Oregon in August 2020:")
print(malheur_august_data[['Cases', 'Deaths']])
# Out:
# County_Info DataFrame:
#      State            Name  Population    Poverty  PerCapitaIncome  ID
# 0  Alabama  Autauga County       55036  14.558333     26588.166667   1
# 1  Alabama  Baldwin County      203360  12.874194     29130.709677   2
# 2  Alabama  Barbour County       26201  27.755556     17891.666667   3
# 3  Alabama     Bibb County       22580  13.925000     21799.000000   4
# 4  Alabama   Blount County       57667  16.422222     21598.444444   5
#
# COVID_monthly DataFrame:
#    ID  Month  Cases  Deaths
# 0   1      3    0.0     0.0
# 1   1      4    0.0     0.0
# 2   1      5    0.0     0.0
# 3   1      6    0.0     0.0
# 4   1      7    0.0     0.0
#
# ID for Malheur County, Oregon: 2231
#
# COVID data for Malheur County, Oregon in August 2020:
#        Cases  Deaths
# 26765    0.0     0.0

# %%
import pandas as pd

# Read the data
acs_data = pd.read_csv('acs2017_census_tract_data.csv')
covid_data = pd.read_csv('COVID_county_data.csv')

# Group and aggregate the ACS data
county_info = acs_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Rename columns for clarity
county_info.columns = ['State', 'Name', 'Population', 'Poverty', 'PerCapitaIncome']

# Add a unique ID to each county
county_info['ID'] = range(1, len(county_info) + 1)

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information
covid_data = covid_data.merge(county_info, left_on=['state', 'county'], right_on=['State', 'Name'])

# Ensure there is a row for each county, year, and month
all_ids = county_info['ID'].unique()
all_months = covid_data['Month'].unique()
all_years = covid_data['Year'].unique()

index = pd.MultiIndex.from_product([all_ids, all_years, all_months], names=['ID', 'Year', 'Month'])
covid_monthly_full = pd.DataFrame(index=index).reset_index()

# Group by ID, Year, and Month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Merge the full DataFrame with the aggregated data
covid_monthly = covid_monthly_full.merge(covid_monthly_agg, on=['ID', 'Year', 'Month'], how='left').fillna(0)

# Rename columns for clarity
covid_monthly.columns = ['ID', 'Year', 'Month', 'Cases', 'Deaths']

# Print the first few rows of each DataFrame
print("County_Info DataFrame:")
print(county_info.head())

print("\nCOVID_monthly DataFrame:")
print(covid_monthly.head())

# Find Malheur County, Oregon in county_info and get its ID
malheur_county_info = county_info[(county_info['Name'] == 'Malheur County') & (county_info['State'] == 'Oregon')]
malheur_county_id = malheur_county_info['ID'].values[0]

print(f"\nID for Malheur County, Oregon: {malheur_county_id}")

# Use the ID to find cases and deaths in COVID_monthly for January 2021 and February 2021
malheur_january_data = covid_monthly[(covid_monthly['ID'] == malheur_county_id) & (covid_monthly['Year'] == 2021) & (covid_monthly['Month'] == 1)]
malheur_february_data = covid_monthly[(covid_monthly['ID'] == malheur_county_id) & (covid_monthly['Year'] == 2021) & (covid_monthly['Month'] == 2)]

print(f"\nCOVID data for Malheur County, Oregon in January 2021:")
print(malheur_january_data[['Cases', 'Deaths']])

print(f"\nCOVID data for Malheur County, Oregon in February 2021:")
print(malheur_february_data[['Cases', 'Deaths']])
# Out:
# County_Info DataFrame:
#      State            Name  Population    Poverty  PerCapitaIncome  ID
# 0  Alabama  Autauga County       55036  14.558333     26588.166667   1
# 1  Alabama  Baldwin County      203360  12.874194     29130.709677   2
# 2  Alabama  Barbour County       26201  27.755556     17891.666667   3
# 3  Alabama     Bibb County       22580  13.925000     21799.000000   4
# 4  Alabama   Blount County       57667  16.422222     21598.444444   5
#
# COVID_monthly DataFrame:
#    ID  Year  Month  Cases  Deaths
# 0   1  2020      3    0.0     0.0
# 1   1  2020      4    0.0     0.0
# 2   1  2020      5    0.0     0.0
# 3   1  2020      6    0.0     0.0
# 4   1  2020      7    0.0     0.0
#
# ID for Malheur County, Oregon: 2231
#
# COVID data for Malheur County, Oregon in January 2021:
#        Cases  Deaths
# 53542    0.0     0.0
#
# COVID data for Malheur County, Oregon in February 2021:
#        Cases  Deaths
# 53543    0.0     0.0

# %%
import pandas as pd

# Read the data
acs_data = pd.read_csv('acs2017_census_tract_data.csv')
covid_data = pd.read_csv('COVID_county_data.csv')

# Group and aggregate the ACS data
county_info = acs_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Rename columns for clarity
county_info.columns = ['State', 'Name', 'Population', 'Poverty', 'PerCapitaIncome']

# Add a unique ID to each county
county_info['ID'] = range(1, len(county_info) + 1)

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information
covid_data = covid_data.merge(county_info, left_on=['state', 'county'], right_on=['State', 'Name'])

# Ensure there is a row for each county, year, and month
all_ids = county_info['ID'].unique()
all_months = covid_data['Month'].unique()
all_years = covid_data['Year'].unique()

index = pd.MultiIndex.from_product([all_ids, all_years, all_months], names=['ID', 'Year', 'Month'])
covid_monthly_full = pd.DataFrame(index=index).reset_index()

# Group by ID, Year, and Month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Merge the full DataFrame with the aggregated data
covid_monthly = covid_monthly_full.merge(covid_monthly_agg, on=['ID', 'Year', 'Month'], how='left').fillna(0)

# Rename columns for clarity
covid_monthly.columns = ['ID', 'Year', 'Month', 'Cases', 'Deaths']

# Print the first few rows of each DataFrame
print("County_Info DataFrame:")
print(county_info.head())

print("\nCOVID_monthly DataFrame:")
print(covid_monthly.head())

# Find Malheur County, Oregon in county_info and get its ID
malheur_county_info = county_info[(county_info['Name'] == 'Malheur County') & (county_info['State'] == 'Oregon')]
malheur_county_id = malheur_county_info['ID'].values[0]

print(f"\nID for Malheur County, Oregon: {malheur_county_id}")

# Print all COVID data for Malheur County, Oregon
malheur_all_data = covid_monthly[covid_monthly['ID'] == malheur_county_id]

print(f"\nAll COVID data for Malheur County, Oregon (ID {malheur_county_id}):")
print(malheur_all_data)
# Out:
# County_Info DataFrame:
#      State            Name  Population    Poverty  PerCapitaIncome  ID
# 0  Alabama  Autauga County       55036  14.558333     26588.166667   1
# 1  Alabama  Baldwin County      203360  12.874194     29130.709677   2
# 2  Alabama  Barbour County       26201  27.755556     17891.666667   3
# 3  Alabama     Bibb County       22580  13.925000     21799.000000   4
# 4  Alabama   Blount County       57667  16.422222     21598.444444   5
#
# COVID_monthly DataFrame:
#    ID  Year  Month  Cases  Deaths
# 0   1  2020      3    0.0     0.0
# 1   1  2020      4    0.0     0.0
# 2   1  2020      5    0.0     0.0
# 3   1  2020      6    0.0     0.0
# 4   1  2020      7    0.0     0.0
#
# ID for Malheur County, Oregon: 2231
#
# All COVID data for Malheur County, Oregon (ID 2231):
#          ID  Year  Month  Cases  Deaths
# 53520  2231  2020      3    0.0     0.0
# 53521  2231  2020      4    0.0     0.0
# 53522  2231  2020      5    0.0     0.0
# ...

# %%
import pandas as pd

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Filter the COVID data for Malheur County, Oregon
malheur_covid_data = covid_data[(covid_data['county'] == 'Malheur') & (covid_data['state'] == 'Oregon')]

# Print the filtered data
print("All COVID data for Malheur County, Oregon:")
print(malheur_covid_data)

# Optional: Save the filtered data to a CSV file
# malheur_covid_data.to_csv('malheur_covid_data.csv', index=False)
# Out:
# All COVID data for Malheur County, Oregon:
#                date   county   state     fips  cases  deaths
# 23275    2020-03-31  Malheur  Oregon  41045.0      1     0.0
# 25473    2020-04-01  Malheur  Oregon  41045.0      1     0.0
# 27745    2020-04-02  Malheur  Oregon  41045.0      1     0.0
# 30078    2020-04-03  Malheur  Oregon  41045.0      2     0.0
# 32468    2020-04-04  Malheur  Oregon  41045.0      2     0.0
# ...             ...      ...     ...      ...    ...     ...
# 1036278  2021-02-16  Malheur  Oregon  41045.0   3302    58.0
# 1039523  2021-02-17  Malheur  Oregon  41045.0   3317    58.0
# 1042768  2021-02-18  Malheur  Oregon  41045.0   3320    58.0
# 1046013  2021-02-19  Malheur  Oregon  41045.0   3326    58.0
# 1049260  2021-02-20  Malheur  Oregon  41045.0   3331    58.0
#
# [327 rows x 6 columns]

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Group by State and County and aggregate the data
county_aggregated_data = census_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Men': 'sum',
    'Women': 'sum',
    'Hispanic': 'mean',
    'White': 'mean',
    'Black': 'mean',
    'Native': 'mean',
    'Asian': 'mean',
    'Pacific': 'mean',
    'VotingAgeCitizen': 'sum',
    'Income': 'mean',
    'IncomeErr': 'mean',
    'IncomePerCap': 'mean',
    'IncomePerCapErr': 'mean',
    'Poverty': 'mean',
    'ChildPoverty': 'mean',
    'Professional': 'mean',
    'Service': 'mean',
    'Office': 'mean',
    'Construction': 'mean',
    'Production': 'mean',
    'Drive': 'mean',
    'Carpool': 'mean',
    'Transit': 'mean',
    'Walk': 'mean',
    'OtherTransp': 'mean',
    'WorkAtHome': 'mean',
    'MeanCommute': 'mean',
    'Employed': 'sum',
    'PrivateWork': 'mean',
    'PublicWork': 'mean',
    'SelfEmployed': 'mean',
    'FamilyWork': 'mean',
    'Unemployment': 'mean'
}).reset_index()

# Print the first few rows of the aggregated data
print("Aggregated County Data:")
print(county_aggregated_data.head())

# Optional: Save the aggregated data to a CSV file
# county_aggregated_data.to_csv('aggregated_county_data.csv', index=False)
# Out:
# Aggregated County Data:
#      State          County  TotalPop    Men   Women  Hispanic      White  \
# 0  Alabama  Autauga County     55036  26899   28137  3.091667  72.325000
# 1  Alabama  Baldwin County    203360  99527  103833  4.012903  83.245161
# 2  Alabama  Barbour County     26201  13976   12225  4.055556  46.022222
# 3  Alabama     Bibb County     22580  12251   10329  2.225000  79.400000
# 4  Alabama   Blount County     57667  28490   29177  9.866667  86.644444
#
#        Black    Native     Asian  ...      Walk  OtherTransp  WorkAtHome  \
# 0  21.608333  0.400000  0.625000  ...  0.700000     1.441667    2.575000
# 1  10.019355  0.887097  0.541935  ...  0.851613     1.351613    5.925806
# 2  47.855556  0.144444  0.488889  ...  2.488889     1.600000    1.222222
# 3  17.550000  0.375000  0.000000  ...  0.500000     1.850000    1.775000
# 4   1.333333  0.355556  0.133333  ...  0.444444     0.344444    1.911111
#
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Group by State and County and aggregate the data
county_aggregated_data = census_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Print the first few rows of the aggregated data to verify
print("Aggregated County Data:")
print(county_aggregated_data.head())

# List of specific counties to extract
specific_counties = [
    {'State': 'Virginia', 'County': 'Loudoun County'},
    {'State': 'Oregon', 'County': 'Washington County'},
    {'State': 'Kentucky', 'County': 'Harlan County'},
    {'State': 'Oregon', 'County': 'Malheur County'}
]

# Extract and print the population, poverty percentage, and per capita income for the specific counties
for county in specific_counties:
    county_data = county_aggregated_data[(county_aggregated_data['State'] == county['State']) & 
                                         (county_aggregated_data['County'] == county['County'])]
    if not county_data.empty:
        print(f"\n{county['County']}, {county['State']}:")
        print(f"Population: {county_data['TotalPop'].values[0]}")
        print(f"Poverty %: {county_data['Poverty'].values[0]:.2f}")
        print(f"Per Capita Income: ${county_data['IncomePerCap'].values[0]:.2f}")
    else:
        print(f"\n{county['County']}, {county['State']} data not found.")
# Out:
# Aggregated County Data:
#      State          County  TotalPop    Poverty  IncomePerCap
# 0  Alabama  Autauga County     55036  14.558333  26588.166667
# 1  Alabama  Baldwin County    203360  12.874194  29130.709677
# 2  Alabama  Barbour County     26201  27.755556  17891.666667
# 3  Alabama     Bibb County     22580  13.925000  21799.000000
# 4  Alabama   Blount County     57667  16.422222  21598.444444
#
# Loudoun County, Virginia:
# Population: 374558
# Poverty %: 3.88
# Per Capita Income: $50391.02
#
# Washington County, Oregon:
# Population: 572071
# Poverty %: 10.45
# Per Capita Income: $34970.82
#
# Harlan County, Kentucky:
# Population: 27548
# Poverty %: 33.32
# Per Capita Income: $16010.36
#
# Malheur County, Oregon:
# Population: 30421
# Poverty %: 24.41
# Per Capita Income: $17966.43

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Group by State and County and aggregate the data
county_aggregated_data = census_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Find the least and most populous counties
least_populous_county = county_aggregated_data.loc[county_aggregated_data['TotalPop'].idxmin()]
most_populous_county = county_aggregated_data.loc[county_aggregated_data['TotalPop'].idxmax()]

# Print the least and most populous counties
print("\nLeast Populous County in the US:")
print(f"{least_populous_county['County']}, {least_populous_county['State']}:")
print(f"Population: {least_populous_county['TotalPop']}")
print(f"Poverty %: {least_populous_county['Poverty']:.2f}")
print(f"Per Capita Income: ${least_populous_county['IncomePerCap']:.2f}")

print("\nMost Populous County in the US:")
print(f"{most_populous_county['County']}, {most_populous_county['State']}:")
print(f"Population: {most_populous_county['TotalPop']}")
print(f"Poverty %: {most_populous_county['Poverty']:.2f}")
print(f"Per Capita Income: ${most_populous_county['IncomePerCap']:.2f}")
# Out:
# Least Populous County in the US:
# Loving County, Texas:
# Population: 74
# Poverty %: 17.10
# Per Capita Income: $35530.00
#
# Most Populous County in the US:
# Los Angeles County, California:
# Population: 10105722
# Poverty %: 17.32
# Per Capita Income: $31389.41

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Group by State and County and aggregate the data
county_aggregated_data = census_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Men': 'sum',
    'Women': 'sum',
    'Hispanic': 'mean',
    'White': 'mean',
    'Black': 'mean',
    'Native': 'mean',
    'Asian': 'mean',
    'Pacific': 'mean',
    'VotingAgeCitizen': 'sum',
    'Income': 'mean',
    'IncomeErr': 'mean',
    'IncomePerCap': 'mean',
    'IncomePerCapErr': 'mean',
    'Poverty': 'mean',
    'ChildPoverty': 'mean',
    'Professional': 'mean',
    'Service': 'mean',
    'Office': 'mean',
    'Construction': 'mean',
    'Production': 'mean',
    'Drive': 'mean',
    'Carpool': 'mean',
    'Transit': 'mean',
    'Walk': 'mean',
    'OtherTransp': 'mean',
    'WorkAtHome': 'mean',
    'MeanCommute': 'mean',
    'Employed': 'sum',
    'PrivateWork': 'mean',
    'PublicWork': 'mean',
    'SelfEmployed': 'mean',
    'FamilyWork': 'mean',
    'Unemployment': 'mean'
}).reset_index()

# Add a unique ID column to the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Print the first few rows of the aggregated data with the ID column
print("Aggregated County Data with ID:")
print(county_aggregated_data.head())

# Optional: Save the aggregated data to a CSV file
# county_aggregated_data.to_csv('aggregated_county_data_with_id.csv', index=False)
# Out:
# Aggregated County Data with ID:
#      State          County  TotalPop    Men   Women  Hispanic      White  \
# 0  Alabama  Autauga County     55036  26899   28137  3.091667  72.325000
# 1  Alabama  Baldwin County    203360  99527  103833  4.012903  83.245161
# 2  Alabama  Barbour County     26201  13976   12225  4.055556  46.022222
# 3  Alabama     Bibb County     22580  12251   10329  2.225000  79.400000
# 4  Alabama   Blount County     57667  28490   29177  9.866667  86.644444
#
#        Black    Native     Asian  ...  OtherTransp  WorkAtHome  MeanCommute  \
# 0  21.608333  0.400000  0.625000  ...     1.441667    2.575000    25.766667
# 1  10.019355  0.887097  0.541935  ...     1.351613    5.925806    27.054839
# 2  47.855556  0.144444  0.488889  ...     1.600000    1.222222    22.744444
# 3  17.550000  0.375000  0.000000  ...     1.850000    1.775000    31.200000
# 4   1.333333  0.355556  0.133333  ...     0.344444    1.911111    35.011111
#
# ...

# %%
import pandas as pd

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Group by state, county, year, and month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['state', 'county', 'Year', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Create a DataFrame to ensure there is a row for each county and each month
all_states = covid_data['state'].unique()
all_counties = covid_data['county'].unique()
all_years = covid_data['Year'].unique()
all_months = range(1, 13)  # Months from 1 to 12

index = pd.MultiIndex.from_product([all_states, all_counties, all_years, all_months], names=['state', 'county', 'Year', 'Month'])
covid_monthly_full = pd.DataFrame(index=index).reset_index()

# Merge the full DataFrame with the aggregated data
covid_monthly = covid_monthly_full.merge(covid_monthly_agg, on=['state', 'county', 'Year', 'Month'], how='left').fillna(0)

# Print the first few rows of the full aggregated data to verify
print("Full Aggregated COVID Data:")
print(covid_monthly.head())

# Optional: Save the full aggregated data to a CSV file
# covid_monthly.to_csv('full_aggregated_covid_data.csv', index=False)
# Out:
# Full Aggregated COVID Data:
#         state     county  Year  Month    cases  deaths
# 0  Washington  Snohomish  2020      1     11.0     0.0
# 1  Washington  Snohomish  2020      2     31.0     0.0
# 2  Washington  Snohomish  2020      3  11076.0   246.0
# 3  Washington  Snohomish  2020      4  58740.0  2366.0
# 4  Washington  Snohomish  2020      5  94534.0  3898.0

# %%
import pandas as pd

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Group by state, county, year, and month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['state', 'county', 'Year', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Create a DataFrame to ensure there is a row for each county and each month
all_states = covid_data['state'].unique()
all_counties = covid_data['county'].unique()
all_years = covid_data['Year'].unique()
all_months = range(1, 13)  # Months from 1 to 12

index = pd.MultiIndex.from_product([all_states, all_counties, all_years, all_months], names=['state', 'county', 'Year', 'Month'])
covid_monthly_full = pd.DataFrame(index=index).reset_index()

# Sort the DataFrame alphabetically by state and within each state by county
covid_monthly_full = covid_monthly_full.sort_values(by=['state', 'county'])

# Add a unique ID for each unique county after sorting
covid_monthly_full['CountyID'] = pd.factorize(covid_monthly_full['state'] + covid_monthly_full['county'])[0] + 1

# Merge the full DataFrame with the aggregated data
covid_monthly = covid_monthly_full.merge(covid_monthly_agg, on=['state', 'county', 'Year', 'Month'], how='left').fillna(0)

# Print the first few rows of the full aggregated data to verify
print("Full Aggregated COVID Data with CountyID:")
print(covid_monthly.head(20))

# Optional: Save the full aggregated data to a CSV file
# covid_monthly.to_csv('full_aggregated_covid_data_with_id.csv', index=False)
# Out:
# Full Aggregated COVID Data with CountyID:
#       state     county  Year  Month  CountyID  cases  deaths
# 0   Alabama  Abbeville  2020      1         1    0.0     0.0
# 1   Alabama  Abbeville  2020      2         1    0.0     0.0
# 2   Alabama  Abbeville  2020      3         1    0.0     0.0
# 3   Alabama  Abbeville  2020      4         1    0.0     0.0
# 4   Alabama  Abbeville  2020      5         1    0.0     0.0
# 5   Alabama  Abbeville  2020      6         1    0.0     0.0
# 6   Alabama  Abbeville  2020      7         1    0.0     0.0
# 7   Alabama  Abbeville  2020      8         1    0.0     0.0
# 8   Alabama  Abbeville  2020      9         1    0.0     0.0
# 9   Alabama  Abbeville  2020     10         1    0.0     0.0
# 10  Alabama  Abbeville  2020     11         1    0.0     0.0
# 11  Alabama  Abbeville  2020     12         1    0.0     0.0
# 12  Alabama  Abbeville  2021      1         1    0.0     0.0
# 13  Alabama  Abbeville  2021      2         1    0.0     0.0
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Remove "County" from the county names in the census data
census_data['County'] = census_data['County'].str.replace(' County', '')

# Group by State and County and aggregate the data
county_aggregated_data = census_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Men': 'sum',
    'Women': 'sum',
    'Hispanic': 'mean',
    'White': 'mean',
    'Black': 'mean',
    'Native': 'mean',
    'Asian': 'mean',
    'Pacific': 'mean',
    'VotingAgeCitizen': 'sum',
    'Income': 'mean',
    'IncomeErr': 'mean',
    'IncomePerCap': 'mean',
    'IncomePerCapErr': 'mean',
    'Poverty': 'mean',
    'ChildPoverty': 'mean',
    'Professional': 'mean',
    'Service': 'mean',
    'Office': 'mean',
    'Construction': 'mean',
    'Production': 'mean',
    'Drive': 'mean',
    'Carpool': 'mean',
    'Transit': 'mean',
    'Walk': 'mean',
    'OtherTransp': 'mean',
    'WorkAtHome': 'mean',
    'MeanCommute': 'mean',
    'Employed': 'sum',
    'PrivateWork': 'mean',
    'PublicWork': 'mean',
    'SelfEmployed': 'mean',
    'FamilyWork': 'mean',
    'Unemployment': 'mean'
}).reset_index()

# Add a unique ID to each county in the census data
county_aggregated_data = county_aggregated_data.sort_values(by=['State', 'County'])
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data, left_on=['state', 'county'], right_on=['State', 'County'], how='left')

# Group by state, county, year, and month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'state', 'county', 'Year', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Create a DataFrame to ensure there is a row for each county and each month
all_ids = county_aggregated_data['ID'].unique()
all_months = range(1, 13)  # Months from 1 to 12

index = pd.MultiIndex.from_product([all_ids, all_months], names=['ID', 'Month'])
covid_monthly_full = pd.DataFrame(index=index).reset_index()

# Merge the full DataFrame with the aggregated data
covid_monthly = covid_monthly_full.merge(covid_monthly_agg, on=['ID', 'Month'], how='left').fillna(0)

# Add state and county names back to the full DataFrame
covid_monthly = covid_monthly.merge(county_aggregated_data[['ID', 'State', 'County']], on='ID', how='left')

# Sort the DataFrame alphabetically by state and within each state by county
covid_monthly = covid_monthly.sort_values(by=['State', 'County', 'Year', 'Month'])

# Print the first few rows of the full aggregated data to verify
print("Full Aggregated COVID Data with CountyID:")
print(covid_monthly.head(20))

# Optional: Save the full aggregated data to a CSV file
# covid_monthly.to_csv('full_aggregated_covid_data_with_id.csv', index=False)
# Out:
# Full Aggregated COVID Data with CountyID:
#     ID  Month    state   county    Year     cases  deaths    State   County
# 2    1      3  Alabama  Autauga  2020.0      43.0     0.0  Alabama  Autauga
# 3    1      4  Alabama  Autauga  2020.0     731.0    45.0  Alabama  Autauga
# 4    1      5  Alabama  Autauga  2020.0    3660.0   107.0  Alabama  Autauga
# 5    1      6  Alabama  Autauga  2020.0   11110.0   228.0  Alabama  Autauga
# 6    1      7  Alabama  Autauga  2020.0   24241.0   551.0  Alabama  Autauga
# 7    1      8  Alabama  Autauga  2020.0   38807.0   699.0  Alabama  Autauga
# 8    1      9  Alabama  Autauga  2020.0   48577.0   733.0  Alabama  Autauga
# 9    1     10  Alabama  Autauga  2020.0   60844.0   893.0  Alabama  Autauga
# 10   1     11  Alabama  Autauga  2020.0   73997.0  1072.0  Alabama  Autauga
# 11   1     12  Alabama  Autauga  2020.0  108652.0  1355.0  Alabama  Autauga
# 0    1      1  Alabama  Autauga  2021.0  156700.0  1773.0  Alabama  Autauga
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Remove "County" from the county names in the census data
census_data['County'] = census_data['County'].str.replace(' County', '')

# Group by State and County and aggregate the data
county_aggregated_data = census_data.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Men': 'sum',
    'Women': 'sum',
    'Hispanic': 'mean',
    'White': 'mean',
    'Black': 'mean',
    'Native': 'mean',
    'Asian': 'mean',
    'Pacific': 'mean',
    'VotingAgeCitizen': 'sum',
    'Income': 'mean',
    'IncomeErr': 'mean',
    'IncomePerCap': 'mean',
    'IncomePerCapErr': 'mean',
    'Poverty': 'mean',
    'ChildPoverty': 'mean',
    'Professional': 'mean',
    'Service': 'mean',
    'Office': 'mean',
    'Construction': 'mean',
    'Production': 'mean',
    'Drive': 'mean',
    'Carpool': 'mean',
    'Transit': 'mean',
    'Walk': 'mean',
    'OtherTransp': 'mean',
    'WorkAtHome': 'mean',
    'MeanCommute': 'mean',
    'Employed': 'sum',
    'PrivateWork': 'mean',
    'PublicWork': 'mean',
    'SelfEmployed': 'mean',
    'FamilyWork': 'mean',
    'Unemployment': 'mean'
}).reset_index()

# Add a unique ID to each county in the census data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID, state, county, year, and month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'state', 'county', 'Year', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Print the first few rows of the aggregated data to verify
print("Aggregated COVID Data with IDs:")
print(covid_monthly_agg.head(20))

# Optional: Save the aggregated data to a CSV file
# covid_monthly_agg.to_csv('aggregated_covid_data_with_id.csv', index=False)
# Out:
# Aggregated COVID Data with IDs:
#      ID    state   county  Year  Month   cases  deaths
# 0   1.0  Alabama  Autauga  2020      3      43     0.0
# 1   1.0  Alabama  Autauga  2020      4     731    45.0
# 2   1.0  Alabama  Autauga  2020      5    3660   107.0
# 3   1.0  Alabama  Autauga  2020      6   11110   228.0
# 4   1.0  Alabama  Autauga  2020      7   24241   551.0
# 5   1.0  Alabama  Autauga  2020      8   38807   699.0
# 6   1.0  Alabama  Autauga  2020      9   48577   733.0
# 7   1.0  Alabama  Autauga  2020     10   60844   893.0
# 8   1.0  Alabama  Autauga  2020     11   73997  1072.0
# 9   1.0  Alabama  Autauga  2020     12  108652  1355.0
# 10  1.0  Alabama  Autauga  2021      1  156700  1773.0
# 11  1.0  Alabama  Autauga  2021      2  118573  1586.0
# 12  2.0  Alabama  Baldwin  2020      3      95     0.0
# 13  2.0  Alabama  Baldwin  2020      4    2877    58.0
# 14  2.0  Alabama  Baldwin  2020      5    7493   220.0
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Men': 'sum',
    'Women': 'sum',
    'Hispanic': 'mean',
    'White': 'mean',
    'Black': 'mean',
    'Native': 'mean',
    'Asian': 'mean',
    'Pacific': 'mean',
    'VotingAgeCitizen': 'sum',
    'Income': 'mean',
    'IncomeErr': 'mean',
    'IncomePerCap': 'mean',
    'IncomePerCapErr': 'mean',
    'Poverty': 'mean',
    'ChildPoverty': 'mean',
    'Professional': 'mean',
    'Service': 'mean',
    'Office': 'mean',
    'Construction': 'mean',
    'Production': 'mean',
    'Drive': 'mean',
    'Carpool': 'mean',
    'Transit': 'mean',
    'Walk': 'mean',
    'OtherTransp': 'mean',
    'WorkAtHome': 'mean',
    'MeanCommute': 'mean',
    'Employed': 'sum',
    'PrivateWork': 'mean',
    'PublicWork': 'mean',
    'SelfEmployed': 'mean',
    'FamilyWork': 'mean',
    'Unemployment': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID, year, and month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Print the first few rows of the aggregated COVID data with IDs to verify
print("Aggregated COVID Data with IDs:")
print(covid_monthly_agg.head(20))

# Optional: Save the aggregated data to a CSV file
# covid_monthly_agg.to_csv('aggregated_covid_data_with_id.csv', index=False)
# Out:
# Aggregated COVID Data with IDs:
#      ID  Year  Month   cases  deaths
# 0   1.0  2020      3      43     0.0
# 1   1.0  2020      4     731    45.0
# 2   1.0  2020      5    3660   107.0
# 3   1.0  2020      6   11110   228.0
# 4   1.0  2020      7   24241   551.0
# 5   1.0  2020      8   38807   699.0
# 6   1.0  2020      9   48577   733.0
# 7   1.0  2020     10   60844   893.0
# 8   1.0  2020     11   73997  1072.0
# 9   1.0  2020     12  108652  1355.0
# 10  1.0  2021      1  156700  1773.0
# 11  1.0  2021      2  118573  1586.0
# 12  2.0  2020      3      95     0.0
# 13  2.0  2020      4    2877    58.0
# 14  2.0  2020      5    7493   220.0
# 15  2.0  2020      6   12318   274.0
# 16  2.0  2020      7   54475   440.0
# 17  2.0  2020      8  120283   981.0
# 18  2.0  2020      9  150651  1425.0
# 19  2.0  2020     10  197611  1996.0

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Men': 'sum',
    'Women': 'sum',
    'Hispanic': 'mean',
    'White': 'mean',
    'Black': 'mean',
    'Native': 'mean',
    'Asian': 'mean',
    'Pacific': 'mean',
    'VotingAgeCitizen': 'sum',
    'Income': 'mean',
    'IncomeErr': 'mean',
    'IncomePerCap': 'mean',
    'IncomePerCapErr': 'mean',
    'Poverty': 'mean',
    'ChildPoverty': 'mean',
    'Professional': 'mean',
    'Service': 'mean',
    'Office': 'mean',
    'Construction': 'mean',
    'Production': 'mean',
    'Drive': 'mean',
    'Carpool': 'mean',
    'Transit': 'mean',
    'Walk': 'mean',
    'OtherTransp': 'mean',
    'WorkAtHome': 'mean',
    'MeanCommute': 'mean',
    'Employed': 'sum',
    'PrivateWork': 'mean',
    'PublicWork': 'mean',
    'SelfEmployed': 'mean',
    'FamilyWork': 'mean',
    'Unemployment': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID, year, and month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Find the ID for Malheur County, Oregon
malheur_id = county_aggregated_data[(county_aggregated_data['State'] == 'Oregon') & 
                                    (county_aggregated_data['County'] == 'Malheur')]['ID'].values[0]

# Filter the COVID data for Malheur County, Oregon, during August 2020, January 2021, and February 2021
malheur_covid_data = covid_monthly_agg[(covid_monthly_agg['ID'] == malheur_id) & 
                                       ((covid_monthly_agg['Year'] == 2020) & (covid_monthly_agg['Month'] == 8) |
                                        (covid_monthly_agg['Year'] == 2021) & (covid_monthly_agg['Month'].isin([1, 2])))]

# Print the filtered COVID data
print(f"COVID data for Malheur County, Oregon (ID {malheur_id}):")
print(malheur_covid_data)
# Out:
# COVID data for Malheur County, Oregon (ID 2231):
#            ID  Year  Month  cases  deaths
# 24754  2231.0  2020      8  28163   459.0
# 24759  2231.0  2021      1  96297  1627.0
# 24760  2231.0  2021      2  65951  1137.0

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K
covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Print the first few rows of the COVID_summary DataFrame to verify
print("COVID_summary DataFrame:")
print(covid_summary.head())

# Optional: Save the COVID_summary DataFrame to a CSV file
# covid_summary.to_csv('COVID_summary.csv', index=False)
# Out:
# COVID_summary DataFrame:
#    ID  TotalPop    Poverty  IncomePerCap  TotalCases  TotalDeaths  \
# 0   1     55036  14.558333  26588.166667    645935.0       9042.0
# 1   2    203360  12.874194  29130.709677   2003567.0      23041.0
# 2   3     26201  27.755556  17891.666667    268771.0       4077.0
# 3   4     22580  13.925000  21799.000000    261043.0       5272.0
# 4   5     57667  16.422222  21598.444444    630106.0       8669.0
#
#    TotalCasesPer100K  TotalDeathsPer100K
# 0       1.173659e+06        16429.246312
# 1       9.852316e+05        11330.153423
# 2       1.025804e+06        15560.474791
# 3       1.156081e+06        23348.095660
# 4       1.092663e+06        15032.861082

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K
covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# Washington County, Oregon:
# Poverty %: 10.45
# Total Cases per 100K: 377110.36
#
# Malheur County, Oregon:
# Poverty %: 24.41
# Total Cases per 100K: 1491187.01
#
# Loudoun County, Virginia:
# Poverty %: 3.88
# Total Cases per 100K: 666505.59
#
# Harlan County, Kentucky:
# Poverty %: 33.32
# Total Cases per 100K: 747727.60

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K
covid_summary['TotalCasesPer100K'] = (covid_summary['TotalCases'] / covid_summary['TotalPop']) * 100000
covid_summary['TotalDeathsPer100K'] = (covid_summary['TotalDeaths'] / covid_summary['TotalPop']) * 100000

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
        print(f"Total Deaths per 100K: {result['TotalDeathsPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# Washington County, Oregon:
# Poverty %: 10.45
# Total Cases per 100K: 377110.36
# Total Deaths per 100K: 3925.21
#
# Malheur County, Oregon:
# Poverty %: 24.41
# Total Cases per 100K: 1491187.01
# Total Deaths per 100K: 25541.57
#
# Loudoun County, Virginia:
# Poverty %: 3.88
# Total Cases per 100K: 666505.59
# Total Deaths per 100K: 9563.27
#
# Harlan County, Kentucky:
# Poverty %: 33.32
# Total Cases per 100K: 747727.60
# Total Deaths per 100K: 14498.33

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['TotalCasesPer100K'] = (covid_summary['TotalCases'] / covid_summary['TotalPop']) * 100000
covid_summary['TotalDeathsPer100K'] = (covid_summary['TotalDeaths'] / covid_summary['TotalPop']) * 100000

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
        print(f"Total Deaths per 100K: {result['TotalDeathsPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# Washington County, Oregon:
# Poverty %: 10.45
# Total Cases per 100K: 377110.36
# Total Deaths per 100K: 3925.21
#
# Malheur County, Oregon:
# Poverty %: 24.41
# Total Cases per 100K: 1491187.01
# Total Deaths per 100K: 25541.57
#
# Loudoun County, Virginia:
# Poverty %: 3.88
# Total Cases per 100K: 666505.59
# Total Deaths per 100K: 9563.27
#
# Harlan County, Kentucky:
# Poverty %: 33.32
# Total Cases per 100K: 747727.60
# Total Deaths per 100K: 14498.33

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['TotalCasesPer100K'] = (covid_summary['TotalCases'] / covid_summary['TotalPop']) * 100000
covid_summary['TotalDeathsPer100K'] = (covid_summary['TotalDeaths'] / covid_summary['TotalPop']) * 100000

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Print the first few rows of the COVID_summary DataFrame to verify
print("COVID_summary DataFrame:")
print(covid_summary.head())

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
        print(f"Total Deaths per 100K: {result['TotalDeathsPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# COVID_summary DataFrame:
#    ID    State   County  TotalPop    Poverty  IncomePerCap  TotalCases  \
# 0   1  Alabama  Autauga     55036  14.558333  26588.166667    645935.0
# 1   2  Alabama  Baldwin    203360  12.874194  29130.709677   2003567.0
# 2   3  Alabama  Barbour     26201  27.755556  17891.666667    268771.0
# 3   4  Alabama     Bibb     22580  13.925000  21799.000000    261043.0
# 4   5  Alabama   Blount     57667  16.422222  21598.444444    630106.0
#
#    TotalDeaths  TotalCasesPer100K  TotalDeathsPer100K
# 0       9042.0       1.173659e+06        16429.246312
# 1      23041.0       9.852316e+05        11330.153423
# 2       4077.0       1.025804e+06        15560.474791
# 3       5272.0       1.156081e+06        23348.095660
# 4       8669.0       1.092663e+06        15032.861082
#
# Washington County, Oregon:
# Poverty %: 10.45
# Total Cases per 100K: 377110.36
# Total Deaths per 100K: 3925.21
#
# Malheur County, Oregon:
# Poverty %: 24.41
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Print the first few rows of the COVID_summary DataFrame to verify
print("COVID_summary DataFrame:")
print(covid_summary.head())

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
        print(f"Total Deaths per 100K: {result['TotalDeathsPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# COVID_summary DataFrame:
#    ID    State   County  TotalPop    Poverty  IncomePerCap  TotalCases  \
# 0   1  Alabama  Autauga     55036  14.558333  26588.166667    645935.0
# 1   2  Alabama  Baldwin    203360  12.874194  29130.709677   2003567.0
# 2   3  Alabama  Barbour     26201  27.755556  17891.666667    268771.0
# 3   4  Alabama     Bibb     22580  13.925000  21799.000000    261043.0
# 4   5  Alabama   Blount     57667  16.422222  21598.444444    630106.0
#
#    TotalDeaths  TotalCasesPer100K  TotalDeathsPer100K
# 0       9042.0       1.173659e+06        16429.246312
# 1      23041.0       9.852316e+05        11330.153423
# 2       4077.0       1.025804e+06        15560.474791
# 3       5272.0       1.156081e+06        23348.095660
# 4       8669.0       1.092663e+06        15032.861082
#
# Washington County, Oregon:
# Poverty %: 10.45
# Total Cases per 100K: 377110.36
# Total Deaths per 100K: 3925.21
#
# Malheur County, Oregon:
# Poverty %: 24.41
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['TotalCasesPer100K'] = (covid_summary['TotalCases'] / covid_summary['TotalPop']) * 100000
covid_summary['TotalDeathsPer100K'] = (covid_summary['TotalDeaths'] / covid_summary['TotalPop']) * 100000

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Print the first few rows of the COVID_summary DataFrame to verify
print("COVID_summary DataFrame:")
print(covid_summary.head())

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
        print(f"Total Deaths per 100K: {result['TotalDeathsPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# COVID_summary DataFrame:
#    ID    State   County  TotalPop    Poverty  IncomePerCap  TotalCases  \
# 0   1  Alabama  Autauga     55036  14.558333  26588.166667    645935.0
# 1   2  Alabama  Baldwin    203360  12.874194  29130.709677   2003567.0
# 2   3  Alabama  Barbour     26201  27.755556  17891.666667    268771.0
# 3   4  Alabama     Bibb     22580  13.925000  21799.000000    261043.0
# 4   5  Alabama   Blount     57667  16.422222  21598.444444    630106.0
#
#    TotalDeaths  TotalCasesPer100K  TotalDeathsPer100K
# 0       9042.0       1.173659e+06        16429.246312
# 1      23041.0       9.852316e+05        11330.153423
# 2       4077.0       1.025804e+06        15560.474791
# 3       5272.0       1.156081e+06        23348.095660
# 4       8669.0       1.092663e+06        15032.861082
#
# Washington County, Oregon:
# Poverty %: 10.45
# Total Cases per 100K: 377110.36
# Total Deaths per 100K: 3925.21
#
# Malheur County, Oregon:
# Poverty %: 24.41
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['PopPer100K'] = covid_summary['TotalPop'] / 100000
covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / covid_summary['PopPer100K']
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / covid_summary['PopPer100K']

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Print the first few rows of the COVID_summary DataFrame to verify
print("COVID_summary DataFrame:")
print(covid_summary.head())

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
        print(f"Total Deaths per 100K: {result['TotalDeathsPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# COVID_summary DataFrame:
#    ID    State   County  TotalPop    Poverty  IncomePerCap  TotalCases  \
# 0   1  Alabama  Autauga     55036  14.558333  26588.166667    645935.0
# 1   2  Alabama  Baldwin    203360  12.874194  29130.709677   2003567.0
# 2   3  Alabama  Barbour     26201  27.755556  17891.666667    268771.0
# 3   4  Alabama     Bibb     22580  13.925000  21799.000000    261043.0
# 4   5  Alabama   Blount     57667  16.422222  21598.444444    630106.0
#
#    TotalDeaths  TotalCasesPer100K  TotalDeathsPer100K
# 0       9042.0       1.173659e+06        16429.246312
# 1      23041.0       9.852316e+05        11330.153423
# 2       4077.0       1.025804e+06        15560.474791
# 3       5272.0       1.156081e+06        23348.095660
# 4       8669.0       1.092663e+06        15032.861082
#
# Washington County, Oregon:
# Poverty %: 10.45
# Total Cases per 100K: 377110.36
# Total Deaths per 100K: 3925.21
#
# Malheur County, Oregon:
# Poverty %: 24.41
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['PopPer100K'] = covid_summary['TotalPop'] / 100000
covid_summary['TotalCasesPer100K'] = (covid_summary['TotalCases'] / covid_summary['PopPer100K'])
covid_summary['TotalDeathsPer100K'] = (covid_summary['TotalDeaths'] / covid_summary['PopPer100K'])

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Print the first few rows of the COVID_summary DataFrame to verify
print("COVID_summary DataFrame:")
print(covid_summary.head())

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
        print(f"Total Deaths per 100K: {result['TotalDeathsPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# COVID_summary DataFrame:
#    ID    State   County  TotalPop    Poverty  IncomePerCap  TotalCases  \
# 0   1  Alabama  Autauga     55036  14.558333  26588.166667    645935.0
# 1   2  Alabama  Baldwin    203360  12.874194  29130.709677   2003567.0
# 2   3  Alabama  Barbour     26201  27.755556  17891.666667    268771.0
# 3   4  Alabama     Bibb     22580  13.925000  21799.000000    261043.0
# 4   5  Alabama   Blount     57667  16.422222  21598.444444    630106.0
#
#    TotalDeaths  TotalCasesPer100K  TotalDeathsPer100K
# 0       9042.0       1.173659e+06        16429.246312
# 1      23041.0       9.852316e+05        11330.153423
# 2       4077.0       1.025804e+06        15560.474791
# 3       5272.0       1.156081e+06        23348.095660
# 4       8669.0       1.092663e+06        15032.861082
#
# Washington County, Oregon:
# Poverty %: 10.45
# Total Cases per 100K: 377110.36
# Total Deaths per 100K: 3925.21
#
# Malheur County, Oregon:
# Poverty %: 24.41
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['TotalCasesPer100K'] = (covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000))
covid_summary['TotalDeathsPer100K'] = (covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000))

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Print the first few rows of the COVID_summary DataFrame to verify
print("COVID_summary DataFrame:")
print(covid_summary.head())

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
        print(f"Total Deaths per 100K: {result['TotalDeathsPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# COVID_summary DataFrame:
#    ID    State   County  TotalPop    Poverty  IncomePerCap  TotalCases  \
# 0   1  Alabama  Autauga     55036  14.558333  26588.166667    645935.0
# 1   2  Alabama  Baldwin    203360  12.874194  29130.709677   2003567.0
# 2   3  Alabama  Barbour     26201  27.755556  17891.666667    268771.0
# 3   4  Alabama     Bibb     22580  13.925000  21799.000000    261043.0
# 4   5  Alabama   Blount     57667  16.422222  21598.444444    630106.0
#
#    TotalDeaths  TotalCasesPer100K  TotalDeathsPer100K
# 0       9042.0       1.173659e+06        16429.246312
# 1      23041.0       9.852316e+05        11330.153423
# 2       4077.0       1.025804e+06        15560.474791
# 3       5272.0       1.156081e+06        23348.095660
# 4       8669.0       1.092663e+06        15032.861082
#
# Washington County, Oregon:
# Poverty %: 10.45
# Total Cases per 100K: 377110.36
# Total Deaths per 100K: 3925.21
#
# Malheur County, Oregon:
# Poverty %: 24.41
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Print the first few rows of the COVID_summary DataFrame to verify
print("COVID_summary DataFrame:")
print(covid_summary.head())

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
        print(f"Total Deaths per 100K: {result['TotalDeathsPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# COVID_summary DataFrame:
#    ID    State   County  TotalPop    Poverty  IncomePerCap  TotalCases  \
# 0   1  Alabama  Autauga     55036  14.558333  26588.166667    645935.0
# 1   2  Alabama  Baldwin    203360  12.874194  29130.709677   2003567.0
# 2   3  Alabama  Barbour     26201  27.755556  17891.666667    268771.0
# 3   4  Alabama     Bibb     22580  13.925000  21799.000000    261043.0
# 4   5  Alabama   Blount     57667  16.422222  21598.444444    630106.0
#
#    TotalDeaths  TotalCasesPer100K  TotalDeathsPer100K
# 0       9042.0       1.173659e+06        16429.246312
# 1      23041.0       9.852316e+05        11330.153423
# 2       4077.0       1.025804e+06        15560.474791
# 3       5272.0       1.156081e+06        23348.095660
# 4       8669.0       1.092663e+06        15032.861082
#
# Washington County, Oregon:
# Poverty %: 10.45
# Total Cases per 100K: 377110.36
# Total Deaths per 100K: 3925.21
#
# Malheur County, Oregon:
# Poverty %: 24.41
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Print the first few rows of the aggregated census data for verification
print("Aggregated Census Data:")
print(county_aggregated_data.head())

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Print the first few rows of the COVID data for verification
print("\nOriginal COVID Data:")
print(covid_data.head())

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Print the first few rows of the merged COVID data for verification
print("\nMerged COVID Data:")
print(covid_data.head())

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Print the first few rows of the aggregated COVID summary data for verification
print("\nAggregated COVID Summary Data:")
print(covid_summary_data.head())

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Print the first few rows of the COVID_summary DataFrame to verify
print("\nCOVID_summary DataFrame:")
print(covid_summary.head())

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
        print(f"Total Deaths per 100K: {result['TotalDeathsPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# Aggregated Census Data:
#      State   County  TotalPop    Poverty  IncomePerCap  ID
# 0  Alabama  Autauga     55036  14.558333  26588.166667   1
# 1  Alabama  Baldwin    203360  12.874194  29130.709677   2
# 2  Alabama  Barbour     26201  27.755556  17891.666667   3
# 3  Alabama     Bibb     22580  13.925000  21799.000000   4
# 4  Alabama   Blount     57667  16.422222  21598.444444   5
#
# Original COVID Data:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0
#
# Merged COVID Data:
#         date     county       state     fips  cases  deaths  Month  Year  \
# 0 2020-01-21  Snohomish  Washington  53061.0      1     0.0      1  2020
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Print the first few rows of the aggregated census data for verification
print("Aggregated Census Data:")
print(county_aggregated_data.head())

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Check for duplicates in the COVID data
covid_data_duplicates = covid_data[covid_data.duplicated()]
print("\nDuplicates in COVID Data:")
print(covid_data_duplicates)

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Print the first few rows of the merged COVID data for verification
print("\nMerged COVID Data:")
print(covid_data.head())

# Group by ID to aggregate cases and deaths over all months
covid_summary_data = covid_data.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Print the first few rows of the aggregated COVID summary data for verification
print("\nAggregated COVID Summary Data:")
print(covid_summary_data.head())

# Rename columns for clarity
covid_summary_data.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge the aggregated census data with the COVID summary data
covid_summary = county_aggregated_data.merge(covid_summary_data, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 
                               'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Print the first few rows of the COVID_summary DataFrame to verify
print("\nCOVID_summary DataFrame:")
print(covid_summary.head())

# Look up Poverty% and TotalCasesPer100K for specified counties
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        print(f"\n{county['County']} County, {county['State']}:")
        print(f"Poverty %: {result['Poverty'].values[0]:.2f}")
        print(f"Total Cases per 100K: {result['TotalCasesPer100K'].values[0]:.2f}")
        print(f"Total Deaths per 100K: {result['TotalDeathsPer100K'].values[0]:.2f}")
    else:
        print(f"\n{county['County']} County, {county['State']} data not found.")
# Out:
# Aggregated Census Data:
#      State   County  TotalPop    Poverty  IncomePerCap  ID
# 0  Alabama  Autauga     55036  14.558333  26588.166667   1
# 1  Alabama  Baldwin    203360  12.874194  29130.709677   2
# 2  Alabama  Barbour     26201  27.755556  17891.666667   3
# 3  Alabama     Bibb     22580  13.925000  21799.000000   4
# 4  Alabama   Blount     57667  16.422222  21598.444444   5
#
# Duplicates in COVID Data:
# Empty DataFrame
# Columns: [date, county, state, fips, cases, deaths]
# Index: []
#
# Merged COVID Data:
#         date     county       state     fips  cases  deaths  Month  Year  \
# 0 2020-01-21  Snohomish  Washington  53061.0      1     0.0      1  2020
# 1 2020-01-22  Snohomish  Washington  53061.0      1     0.0      1  2020
# 2 2020-01-23  Snohomish  Washington  53061.0      1     0.0      1  2020
# 3 2020-01-24       Cook    Illinois  17031.0      1     0.0      1  2020
# 4 2020-01-24  Snohomish  Washington  53061.0      1     0.0      1  2020
#
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Men': 'sum',
    'Women': 'sum',
    'Hispanic': 'mean',
    'White': 'mean',
    'Black': 'mean',
    'Native': 'mean',
    'Asian': 'mean',
    'Pacific': 'mean',
    'VotingAgeCitizen': 'sum',
    'Income': 'mean',
    'IncomeErr': 'mean',
    'IncomePerCap': 'mean',
    'IncomePerCapErr': 'mean',
    'Poverty': 'mean',
    'ChildPoverty': 'mean',
    'Professional': 'mean',
    'Service': 'mean',
    'Office': 'mean',
    'Construction': 'mean',
    'Production': 'mean',
    'Drive': 'mean',
    'Carpool': 'mean',
    'Transit': 'mean',
    'Walk': 'mean',
    'OtherTransp': 'mean',
    'WorkAtHome': 'mean',
    'MeanCommute': 'mean',
    'Employed': 'sum',
    'PrivateWork': 'mean',
    'PublicWork': 'mean',
    'SelfEmployed': 'mean',
    'FamilyWork': 'mean',
    'Unemployment': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID, year, and month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Find the ID for Malheur County, Oregon
malheur_id = county_aggregated_data[(county_aggregated_data['State'] == 'Oregon') & 
                                    (county_aggregated_data['County'] == 'Malheur')]['ID'].values[0]

# Filter the COVID data for Malheur County, Oregon, during August 2020, January 2021, and February 2021
malheur_covid_data = covid_monthly_agg[(covid_monthly_agg['ID'] == malheur_id) & 
                                       ((covid_monthly_agg['Year'] == 2020) & (covid_monthly_agg['Month'] == 8) |
                                        (covid_monthly_agg['Year'] == 2021) & (covid_monthly_agg['Month'].isin([1, 2])))]

# Print the filtered COVID data
print(f"COVID data for Malheur County, Oregon (ID {malheur_id}):")
print(malheur_covid_data)
# Out:
# COVID data for Malheur County, Oregon (ID 2231):
#            ID  Year  Month  cases  deaths
# 24754  2231.0  2020      8  28163   459.0
# 24759  2231.0  2021      1  96297  1627.0
# 24760  2231.0  2021      2  65951  1137.0

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Print the first few rows of the aggregated census data for verification
print("Aggregated Census Data:")
print(county_aggregated_data.head())

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Check for duplicates in the COVID data
covid_data_duplicates = covid_data[covid_data.duplicated()]
print("\nDuplicates in COVID Data:")
print(covid_data_duplicates)

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Check for duplicates in the merged COVID data
merged_covid_data_duplicates = covid_data[covid_data.duplicated()]
print("\nDuplicates in Merged COVID Data:")
print(merged_covid_data_duplicates)

# Group by ID, year, and month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Print the first few rows of the aggregated COVID monthly data for verification
print("\nAggregated COVID Monthly Data:")
print(covid_monthly_agg.head())

# Find the ID for Malheur County, Oregon
malheur_id = county_aggregated_data[(county_aggregated_data['State'] == 'Oregon') & 
                                    (county_aggregated_data['County'] == 'Malheur')]['ID'].values[0]

# Filter the COVID data for Malheur County, Oregon, during August 2020, January 2021, and February 2021
malheur_covid_data = covid_monthly_agg[(covid_monthly_agg['ID'] == malheur_id) & 
                                       ((covid_monthly_agg['Year'] == 2020) & (covid_monthly_agg['Month'] == 8) |
                                        (covid_monthly_agg['Year'] == 2021) & (covid_monthly_agg['Month'].isin([1, 2])))]

# Print the filtered COVID data
print(f"\nCOVID data for Malheur County, Oregon (ID {malheur_id}):")
print(malheur_covid_data)

# Verify the sum of cases and deaths for Malheur County to ensure correctness
malheur_total_cases = covid_monthly_agg[covid_monthly_agg['ID'] == malheur_id]['cases'].sum()
malheur_total_deaths = covid_monthly_agg[covid_monthly_agg['ID'] == malheur_id]['deaths'].sum()
print(f"\nTotal cases for Malheur County, Oregon: {malheur_total_cases}")
print(f"Total deaths for Malheur County, Oregon: {malheur_total_deaths}")

# Print the population of Malheur County for comparison
malheur_population = county_aggregated_data[county_aggregated_data['ID'] == malheur_id]['TotalPop'].values[0]
print(f"Population of Malheur County, Oregon: {malheur_population}")
# Out:
# Aggregated Census Data:
#      State   County  TotalPop    Poverty  IncomePerCap  ID
# 0  Alabama  Autauga     55036  14.558333  26588.166667   1
# 1  Alabama  Baldwin    203360  12.874194  29130.709677   2
# 2  Alabama  Barbour     26201  27.755556  17891.666667   3
# 3  Alabama     Bibb     22580  13.925000  21799.000000   4
# 4  Alabama   Blount     57667  16.422222  21598.444444   5
#
# Duplicates in COVID Data:
# Empty DataFrame
# Columns: [date, county, state, fips, cases, deaths]
# Index: []
#
# Duplicates in Merged COVID Data:
# Empty DataFrame
# Columns: [date, county, state, fips, cases, deaths, Month, Year, State, County, ID]
# Index: []
#
# Aggregated COVID Monthly Data:
#     ID  Year  Month  cases  deaths
# 0  1.0  2020      3     43     0.0
# 1  1.0  2020      4    731    45.0
# 2  1.0  2020      5   3660   107.0
# 3  1.0  2020      6  11110   228.0
# 4  1.0  2020      7  24241   551.0
#
# COVID data for Malheur County, Oregon (ID 2231):
# ...

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Men': 'sum',
    'Women': 'sum',
    'Hispanic': 'mean',
    'White': 'mean',
    'Black': 'mean',
    'Native': 'mean',
    'Asian': 'mean',
    'Pacific': 'mean',
    'VotingAgeCitizen': 'sum',
    'Income': 'mean',
    'IncomeErr': 'mean',
    'IncomePerCap': 'mean',
    'IncomePerCapErr': 'mean',
    'Poverty': 'mean',
    'ChildPoverty': 'mean',
    'Professional': 'mean',
    'Service': 'mean',
    'Office': 'mean',
    'Construction': 'mean',
    'Production': 'mean',
    'Drive': 'mean',
    'Carpool': 'mean',
    'Transit': 'mean',
    'Walk': 'mean',
    'OtherTransp': 'mean',
    'WorkAtHome': 'mean',
    'MeanCommute': 'mean',
    'Employed': 'sum',
    'PrivateWork': 'mean',
    'PublicWork': 'mean',
    'SelfEmployed': 'mean',
    'FamilyWork': 'mean',
    'Unemployment': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID, year, and month, then aggregate cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Find the ID for Malheur County, Oregon
malheur_id = county_aggregated_data[(county_aggregated_data['State'] == 'Oregon') & 
                                    (county_aggregated_data['County'] == 'Malheur')]['ID'].values[0]

# Filter the COVID data for Malheur County, Oregon, during August 2020, January 2021, and February 2021
malheur_covid_data = covid_monthly_agg[(covid_monthly_agg['ID'] == malheur_id) & 
                                       ((covid_monthly_agg['Year'] == 2020) & (covid_monthly_agg['Month'] == 8) |
                                        (covid_monthly_agg['Year'] == 2021) & (covid_monthly_agg['Month'].isin([1, 2])))]

# Print the filtered COVID data
print(f"COVID data for Malheur County, Oregon (ID {malheur_id}):")
print(malheur_covid_data)

# Print all aggregated COVID monthly data for Malheur County, Oregon
all_malheur_covid_data = covid_monthly_agg[covid_monthly_agg['ID'] == malheur_id]
print(f"\nAll aggregated COVID monthly data for Malheur County, Oregon (ID {malheur_id}):")
print(all_malheur_covid_data)
# Out:
# COVID data for Malheur County, Oregon (ID 2231):
#            ID  Year  Month  cases  deaths
# 24754  2231.0  2020      8  28163   459.0
# 24759  2231.0  2021      1  96297  1627.0
# 24760  2231.0  2021      2  65951  1137.0
#
# All aggregated COVID monthly data for Malheur County, Oregon (ID 2231):
#            ID  Year  Month  cases  deaths
# 24749  2231.0  2020      3      1     0.0
# 24750  2231.0  2020      4    125     0.0
# 24751  2231.0  2020      5    626     0.0
# 24752  2231.0  2020      6   1447    24.0
# 24753  2231.0  2020      7  12773   130.0
# 24754  2231.0  2020      8  28163   459.0
# 24755  2231.0  2020      9  43150   693.0
# 24756  2231.0  2020     10  56398  1061.0
# 24757  2231.0  2020     11  65787  1174.0
# 24758  2231.0  2020     12  82916  1465.0
# 24759  2231.0  2021      1  96297  1627.0
# 24760  2231.0  2021      2  65951  1137.0

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Men': 'sum',
    'Women': 'sum',
    'Hispanic': 'mean',
    'White': 'mean',
    'Black': 'mean',
    'Native': 'mean',
    'Asian': 'mean',
    'Pacific': 'mean',
    'VotingAgeCitizen': 'sum',
    'Income': 'mean',
    'IncomeErr': 'mean',
    'IncomePerCap': 'mean',
    'IncomePerCapErr': 'mean',
    'Poverty': 'mean',
    'ChildPoverty': 'mean',
    'Professional': 'mean',
    'Service': 'mean',
    'Office': 'mean',
    'Construction': 'mean',
    'Production': 'mean',
    'Drive': 'mean',
    'Carpool': 'mean',
    'Transit': 'mean',
    'Walk': 'mean',
    'OtherTransp': 'mean',
    'WorkAtHome': 'mean',
    'MeanCommute': 'mean',
    'Employed': 'sum',
    'PrivateWork': 'mean',
    'PublicWork': 'mean',
    'SelfEmployed': 'mean',
    'FamilyWork': 'mean',
    'Unemployment': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID, year, and month, then get the maximum number of cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'max',
    'deaths': 'max'
}).reset_index()

# Find the ID for Malheur County, Oregon
malheur_id = county_aggregated_data[(county_aggregated_data['State'] == 'Oregon') & 
                                    (county_aggregated_data['County'] == 'Malheur')]['ID'].values[0]

# Filter the COVID data for Malheur County, Oregon, during August 2020, January 2021, and February 2021
malheur_covid_data = covid_monthly_agg[(covid_monthly_agg['ID'] == malheur_id) & 
                                       ((covid_monthly_agg['Year'] == 2020) & (covid_monthly_agg['Month'] == 8) |
                                        (covid_monthly_agg['Year'] == 2021) & (covid_monthly_agg['Month'].isin([1, 2])))]

# Print the filtered COVID data
print(f"COVID data for Malheur County, Oregon (ID {malheur_id}):")
print(malheur_covid_data)

# Print all aggregated COVID monthly data for Malheur County, Oregon
all_malheur_covid_data = covid_monthly_agg[covid_monthly_agg['ID'] == malheur_id]
print(f"\nAll aggregated COVID monthly data for Malheur County, Oregon (ID {malheur_id}):")
print(all_malheur_covid_data)
# Out:
# COVID data for Malheur County, Oregon (ID 2231):
#            ID  Year  Month  cases  deaths
# 24754  2231.0  2020      8   1179    19.0
# 24759  2231.0  2021      1   3259    56.0
# 24760  2231.0  2021      2   3331    58.0
#
# All aggregated COVID monthly data for Malheur County, Oregon (ID 2231):
#            ID  Year  Month  cases  deaths
# 24749  2231.0  2020      3      1     0.0
# 24750  2231.0  2020      4      8     0.0
# 24751  2231.0  2020      5     33     0.0
# 24752  2231.0  2020      6    108     1.0
# 24753  2231.0  2020      7    646     9.0
# 24754  2231.0  2020      8   1179    19.0
# 24755  2231.0  2020      9   1650    30.0
# 24756  2231.0  2020     10   1977    38.0
# 24757  2231.0  2020     11   2409    44.0
# 24758  2231.0  2020     12   2914    50.0
# 24759  2231.0  2021      1   3259    56.0
# 24760  2231.0  2021      2   3331    58.0

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Men': 'sum',
    'Women': 'sum',
    'Hispanic': 'mean',
    'White': 'mean',
    'Black': 'mean',
    'Native': 'mean',
    'Asian': 'mean',
    'Pacific': 'mean',
    'VotingAgeCitizen': 'sum',
    'Income': 'mean',
    'IncomeErr': 'mean',
    'IncomePerCap': 'mean',
    'IncomePerCapErr': 'mean',
    'Poverty': 'mean',
    'ChildPoverty': 'mean',
    'Professional': 'mean',
    'Service': 'mean',
    'Office': 'mean',
    'Construction': 'mean',
    'Production': 'mean',
    'Drive': 'mean',
    'Carpool': 'mean',
    'Transit': 'mean',
    'Walk': 'mean',
    'OtherTransp': 'mean',
    'WorkAtHome': 'mean',
    'MeanCommute': 'mean',
    'Employed': 'sum',
    'PrivateWork': 'mean',
    'PublicWork': 'mean',
    'SelfEmployed': 'mean',
    'FamilyWork': 'mean',
    'Unemployment': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID, year, and month, then get the maximum number of cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'max',
    'deaths': 'max'
}).reset_index()

# Aggregate the total cases and deaths for each county over all months
total_cases_deaths = covid_monthly_agg.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
total_cases_deaths.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge with the aggregated census data
covid_summary = county_aggregated_data[['ID', 'TotalPop', 'Poverty', 'IncomePerCap']].merge(total_cases_deaths, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'TotalPop', 'Poverty', 'IncomePerCap', 'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Print the first few rows of the COVID_summary DataFrame to verify
print("COVID_summary DataFrame:")
print(covid_summary.head())
# Out:
# COVID_summary DataFrame:
#    ID  TotalPop    Poverty  IncomePerCap  TotalCases  TotalDeaths  \
# 0   1     55036  14.558333  26588.166667     25946.0        366.0
# 1   2    203360  12.874194  29130.709677     81398.0        955.0
# 2   3     26201  27.755556  17891.666667     10552.0        164.0
# 3   4     22580  13.925000  21799.000000     10495.0        212.0
# 4   5     57667  16.422222  21598.444444     25460.0        384.0
#
#    TotalCasesPer100K  TotalDeathsPer100K
# 0       47143.687768          665.019260
# 1       40026.553895          469.610543
# 2       40273.272013          625.930308
# 3       46479.185120          938.883968
# 4       44150.033815          665.892105

# %%
import pandas as pd

# Read the census data from the CSV file
census_data = pd.read_csv('acs2017_census_tract_data.csv')

# Create a copy of the original census data to work on for aggregation
census_data_copy = census_data.copy()

# Remove "County" from the county names in the copy of the census data
census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

# Group by State and County and aggregate the data in the copy
county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

# Add a unique ID to each county in the aggregated data
county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

# Read the COVID data from the CSV file
covid_data = pd.read_csv('COVID_county_data.csv')

# Convert the date column to datetime and extract the month and year
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

# Merge the COVID data with the county information to get the IDs
covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], 
                              left_on=['state', 'county'], 
                              right_on=['State', 'County'], 
                              how='left')

# Group by ID, year, and month, then get the maximum number of cases and deaths
covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'max',
    'deaths': 'max'
}).reset_index()

# Aggregate the total cases and deaths for each county over all months
total_cases_deaths = covid_monthly_agg.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

# Rename columns for clarity
total_cases_deaths.columns = ['ID', 'TotalCases', 'TotalDeaths']

# Merge with the aggregated census data
covid_summary = county_aggregated_data[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap']].merge(total_cases_deaths, on='ID', how='left').fillna(0)

# Compute TotalCasesPer100K and TotalDeathsPer100K correctly
covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

# Select and reorder the columns as specified
covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

# Specify the counties to print
specified_counties = [
    {'State': 'Oregon', 'County': 'Washington'},
    {'State': 'Oregon', 'County': 'Malheur'},
    {'State': 'Virginia', 'County': 'Loudoun'},
    {'State': 'Kentucky', 'County': 'Harlan'}
]

# Create and print the table
print(f"{'County':<30} {'Poverty %':<10} {'TotalCasesPer100K':<20}")
for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        county_name = f"{county['County']} County, {county['State']}"
        poverty = result['Poverty'].values[0]
        total_cases_per_100k = result['TotalCasesPer100K'].values[0]
        print(f"{county_name:<30} {poverty:<10.2f} {total_cases_per_100k:<20.2f}")
    else:
        print(f"{county['County']} County, {county['State']} data not found.")
# Out:
# County                         Poverty %  TotalCasesPer100K
# Washington County, Oregon      10.45      15263.32
# Malheur County, Oregon         24.41      57575.36
# Loudoun County, Virginia       3.88       26807.86
# Harlan County, Kentucky        33.32      31167.42

# %%
import pandas as pd

census_data = pd.read_csv('acs2017_census_tract_data.csv')
census_data_copy = census_data.copy()

census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

covid_data = pd.read_csv('COVID_county_data.csv')

covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], left_on=['state', 'county'], right_on=['State', 'County'], how='left')

covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'max',
    'deaths': 'max'
}).reset_index()

total_cases_deaths = covid_monthly_agg.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

total_cases_deaths.columns = ['ID', 'TotalCases', 'TotalDeaths']

covid_summary = county_aggregated_data[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap']].merge(total_cases_deaths, on='ID', how='left').fillna(0)

covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

specified_counties = [{'State': 'Oregon', 'County': 'Washington'},{'State': 'Oregon', 'County': 'Malheur'},{'State': 'Virginia', 'County': 'Loudoun'},{'State': 'Kentucky', 'County': 'Harlan'}]

print(f"{'County':<30} {'Poverty %':<10} {'TotalCasesPer100K':<20}")
for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        county_name = f"{county['County']} County, {county['State']}"
        poverty = result['Poverty'].values[0]
        total_cases_per_100k = result['TotalCasesPer100K'].values[0]
        print(f"{county_name:<30} {poverty:<10.2f} {total_cases_per_100k:<20.2f}")
    else:
        print(f"{county['County']} County, {county['State']} data not found.")
# Out:
# County                         Poverty %  TotalCasesPer100K
# Washington County, Oregon      10.45      15263.32
# Malheur County, Oregon         24.41      57575.36
# Loudoun County, Virginia       3.88       26807.86
# Harlan County, Kentucky        33.32      31167.42

# %%
import pandas as pd

census_data = pd.read_csv('acs2017_census_tract_data.csv')
census_data_copy = census_data.copy()

census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

covid_data = pd.read_csv('COVID_county_data.csv')

covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], left_on=['state', 'county'], right_on=['State', 'County'], how='left')

covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'max',
    'deaths': 'max'
}).reset_index()

total_cases_deaths = covid_monthly_agg.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

total_cases_deaths.columns = ['ID', 'TotalCases', 'TotalDeaths']

covid_summary = county_aggregated_data[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap']].merge(total_cases_deaths, on='ID', how='left').fillna(0)

covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

specified_counties = [{'State': 'Oregon', 'County': 'Washington'},{'State': 'Oregon', 'County': 'Malheur'},{'State': 'Virginia', 'County': 'Loudoun'},{'State': 'Kentucky', 'County': 'Harlan'}]

print(f"{'County':<30} {'Poverty %':<10} {'TotalCasesPer100K':<20}")
for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        county_name = f"{county['County']} County, {county['State']}"
        poverty = result['Poverty'].values[0]
        total_cases_per_100k = result['TotalCasesPer100K'].values[0]
        print(f"{county_name} {poverty} {total_cases_per_100k}")
    else:
        print(f"{county['County']} County, {county['State']} data not found.")
# Out:
# County                         Poverty %  TotalCasesPer100K
# Washington County, Oregon 10.446153846153846 15263.315217866313
# Malheur County, Oregon 24.414285714285715 57575.359126918906
# Loudoun County, Virginia 3.884375 26807.86420260681
# Harlan County, Kentucky 33.31818181818182 31167.41687236823

# %%
import pandas as pd

census_data = pd.read_csv('acs2017_census_tract_data.csv')
census_data_copy = census_data.copy()

census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

covid_data = pd.read_csv('COVID_county_data.csv')

covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], left_on=['state', 'county'], right_on=['State', 'County'], how='left')

covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'max',
    'deaths': 'max'
}).reset_index()

total_cases_deaths = covid_monthly_agg.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

total_cases_deaths.columns = ['ID', 'TotalCases', 'TotalDeaths']

covid_summary = county_aggregated_data[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap']].merge(total_cases_deaths, on='ID', how='left').fillna(0)

covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

specified_counties = [{'State': 'Oregon', 'County': 'Washington'},{'State': 'Oregon', 'County': 'Malheur'},{'State': 'Virginia', 'County': 'Loudoun'},{'State': 'Kentucky', 'County': 'Harlan'}]

print(f"{'County'} {'%Poverty'} {'TotalCasesPer100K'}")
for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        county_name = f"{county['County']} County, {county['State']}"
        poverty = result['Poverty'].values[0]
        total_cases_per_100k = result['TotalCasesPer100K'].values[0]
        print(f"{county_name} {poverty} {total_cases_per_100k}")
    else:
        print(f"{county['County']} County, {county['State']} data not found.")
# Out:
# County %Poverty TotalCasesPer100K
# Washington County, Oregon 10.446153846153846 15263.315217866313
# Malheur County, Oregon 24.414285714285715 57575.359126918906
# Loudoun County, Virginia 3.884375 26807.86420260681
# Harlan County, Kentucky 33.31818181818182 31167.41687236823

# %%
import pandas as pd

census_data = pd.read_csv('acs2017_census_tract_data.csv')
census_data_copy = census_data.copy()

census_data_copy['County'] = census_data_copy['County'].str.replace(' County', '')

county_aggregated_data = census_data_copy.groupby(['State', 'County']).agg({
    'TotalPop': 'sum',
    'Poverty': 'mean',
    'IncomePerCap': 'mean'
}).reset_index()

county_aggregated_data['ID'] = range(1, len(county_aggregated_data) + 1)

covid_data = pd.read_csv('COVID_county_data.csv')

covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['Month'] = covid_data['date'].dt.month
covid_data['Year'] = covid_data['date'].dt.year

covid_data = covid_data.merge(county_aggregated_data[['State', 'County', 'ID']], left_on=['state', 'county'], right_on=['State', 'County'], how='left')

covid_monthly_agg = covid_data.groupby(['ID', 'Year', 'Month']).agg({
    'cases': 'max',
    'deaths': 'max'
}).reset_index()

total_cases_deaths = covid_monthly_agg.groupby('ID').agg({
    'cases': 'sum',
    'deaths': 'sum'
}).reset_index()

total_cases_deaths.columns = ['ID', 'TotalCases', 'TotalDeaths']

covid_summary = county_aggregated_data[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap']].merge(total_cases_deaths, on='ID', how='left').fillna(0)

covid_summary['TotalCasesPer100K'] = covid_summary['TotalCases'] / (covid_summary['TotalPop'] / 100000)
covid_summary['TotalDeathsPer100K'] = covid_summary['TotalDeaths'] / (covid_summary['TotalPop'] / 100000)

covid_summary = covid_summary[['ID', 'State', 'County', 'TotalPop', 'Poverty', 'IncomePerCap', 'TotalCases', 'TotalDeaths', 'TotalCasesPer100K', 'TotalDeathsPer100K']]

specified_counties = [{'State': 'Oregon', 'County': 'Washington'},{'State': 'Oregon', 'County': 'Malheur'},{'State': 'Virginia', 'County': 'Loudoun'},{'State': 'Kentucky', 'County': 'Harlan'}]

print(f"{'County'} {'%Poverty'} {'TotalCasesPer100K'}")
for county in specified_counties:
    result = covid_summary[(covid_summary['State'] == county['State']) & 
                           (covid_summary['County'] == county['County'])]
    if not result.empty:
        county_name = f"{county['County']}"
        poverty = result['Poverty'].values[0]
        total_cases_per_100k = result['TotalCasesPer100K'].values[0]
        print(f"{county_name} {poverty} {total_cases_per_100k}")
    else:
        print(f"{county['County']} County, {county['State']} data not found.")
# Out:
# County %Poverty TotalCasesPer100K
# Washington 10.446153846153846 15263.315217866313
# Malheur 24.414285714285715 57575.359126918906
# Loudoun 3.884375 26807.86420260681
# Harlan 33.31818181818182 31167.41687236823
